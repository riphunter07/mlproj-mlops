# %%
import pandas as pd

df = pd.read_csv("../data/processed/features_sales.csv")

df.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  2010-03-05    1554806.68             0        46.50       2.625
# 1      1  2010-03-12    1439541.59             0        57.79       2.667
# 2      1  2010-03-19    1472515.79             0        54.58       2.720
# 3      1  2010-03-26    1404429.92             0        51.45       2.732
# 4      1  2010-04-02    1594968.28             0        62.27       2.719
#
#           CPI  Unemployment  year  month  week       lag_1       lag_2  \
# 0  211.350143         8.106  2010      3     9  1409727.59  1611968.17
# 1  211.380643         8.106  2010      3    10  1554806.68  1409727.59
# 2  211.215635         8.106  2010      3    11  1439541.59  1554806.68
# 3  211.018042         8.106  2010      3    12  1472515.79  1439541.59
# 4  210.820450         7.808  2010      4    13  1404429.92  1472515.79
#
#         lag_4  rolling_mean_4  rolling_std_4  day_of_week  week_of_year  \
# ...

# %%
import seaborn as sns

sns.scatterplot(x=df["lag_1"], y=df["Weekly_Sales"])
# Out:
# <Axes: xlabel='lag_1', ylabel='Weekly_Sales'>
